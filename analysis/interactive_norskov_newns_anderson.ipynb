# %%
# %matplotlib inline
from ipywidgets import interactive, fixed, widgets
import numpy as np
from plot_params import get_plot_params
get_plot_params()
from interactive_utilities import interactive_norskov_newns_anderson

# %%
w = interactive(interactive_norskov_newns_anderson,
                alpha = widgets.FloatSlider(min=0.0, max=4, step=0.01, description=r"$\alpha$"),
#                 beta = widgets.FloatSlider(min=0.001, max=4, step=0.01, description=r"$\beta$"),
                Delta0_mag = widgets.FloatSlider(min=0, max=6, step=0.1, description=r"$\Delta_0$"),
#                 constant = widgets.IntSlider(min=-7, max=0, description="Constant"),
                adsorbate = widgets.Dropdown(options=["O", "C"], description="Adsorbate")
               )
w
# Out:
# interactive(children=(Dropdown(description='Adsorbate', options=('O', 'C'), value='O'), FloatSlider(value=0.0,…
